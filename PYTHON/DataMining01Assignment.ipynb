# %% [markdown]
# # DATA MINING ASSIGNMENT
# ## Wine Classification
# ### Name: Ramadevi G
# ### Roll No.: 2024MCS120005

# %% [markdown]
# 1, Download the dataset from https://archive.ics.uci.edu/ml/datasets/Wine. Read the description of the dataset.
#
# The dataset has various classes of wine grown in Italy and classified based on 13 variables. It is a chemical analysis of the wines and then classifying them based on the 13 variables.

# %% [markdown]
# 2, Load the dataset. Then, based on your X and y, answer the following questions

# %%
# %pip install ucimlrepo
# %pip install pandas
# %pip install scikit-learn
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\willy\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\willy\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# ...

# %%
from ucimlrepo import fetch_ucirepo 
import pandas as pd
import sklearn
  
# fetch dataset 
wine = fetch_ucirepo(id=109) 
type(wine)
# Out:
# ucimlrepo.dotdict.dotdict

# %%
# The features of the wine ie the composition of the 13 chemical components is chosen as X
X = wine.data.features
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Alcohol                       178 non-null    float64
#  1   Malicacid                     178 non-null    float64
#  2   Ash                           178 non-null    float64
#  3   Alcalinity_of_ash             178 non-null    float64
#  4   Magnesium                     178 non-null    int64
#  5   Total_phenols                 178 non-null    float64
#  6   Flavanoids                    178 non-null    float64
#  7   Nonflavanoid_phenols          178 non-null    float64
#  8   Proanthocyanins               178 non-null    float64
#  9   Color_intensity               178 non-null    float64
#  10  Hue                           178 non-null    float64
#  11  0D280_0D315_of_diluted_wines  178 non-null    float64
# ...

# %%
# Y is the class of the wine
y = wine.data.targets
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   class   178 non-null    int64
# dtypes: int64(1)
# memory usage: 1.5 KB

# %% [markdown]
# #### How many records are available?
# The X has 178 records with 13 features each.
#
# Y has the same number of records ie 178 entries

# %% [markdown]
# • Are there missing values?

# %%
X.isnull().sum()
# Out:
# Alcohol                         0
# Malicacid                       0
# Ash                             0
# Alcalinity_of_ash               0
# Magnesium                       0
# Total_phenols                   0
# Flavanoids                      0
# Nonflavanoid_phenols            0
# Proanthocyanins                 0
# Color_intensity                 0
# Hue                             0
# 0D280_0D315_of_diluted_wines    0
# Proline                         0
# dtype: int64

# %%
y.isnull().sum()
# Out:
# class    0
# dtype: int64

# %% [markdown]
# There are no missing values

# %% [markdown]
# • How many elements does each class contain?

# %%
X.describe()
# Out:
#           Alcohol   Malicacid         Ash  Alcalinity_of_ash   Magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
class1 = 0
class2 = 0
class3 = 0
for i in wineclass['class']:
    if i == 1:
        class1 += 1
    elif i == 2:
        class2 += 1
    else: #since no null values
        class3 += 1
print(f"The number of wines of class 1 is {class1} nos.\nThe number of wines of class 2 is {class2} nos.\nThe number of wines of class 3 is {class3} nos.")
# Out:
# The number of wines of class 1 is 59 nos.
# The number of wines of class 2 is 71 nos.
# The number of wines of class 3 is 48 nos.

# %% [markdown]
# 3, Create a DecisionTreeClassifier object with the default configuration (i.e. without passing any parameters to the constructor). Train the classifier using your X and y.

# %%
from sklearn.tree import DecisionTreeClassifier
wineclassifier = DecisionTreeClassifier()

# %%
wineclassifier.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# 4, Now visualize it using plot_tree(), plots the tree in a matplotlib-based, interactive window. After you successfully plotted a tree, you can take a closer look at the result and draw some conclusions. In particular, what information is contained in each node?

# %%
wineclasses = ['1', '2', '3'] #wineclassifier.classes_ returns integers

# %%
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize = (200,200))
tree.plot_tree(wineclassifier, feature_names = X.columns, class_names = wineclasses, filled=True)
plt.show()

# %% [markdown]
# The decision tree starts with the presence of proline in the classes of wine and based on the quantity of each of the 13 features, it classifies the wine into class 1, 2 or 3. Each node contains the gini coefficient(as the criterion has the default 'gini' parameter), the number of samples being classified, values in each class is displayed as an array of 3 numbers and the class to which the samples belong to. In case of tail nodes the class is displayed and in other nodes the class with maximum sample is displayed.

# %% [markdown]
# 5, Given the dataset X, you can get the predictions of the classifier (one for each entry in X) by calling the predict() of DecisionTreeClassifier. Then, use the accuracy_score() function (which you can import from sklearn.metrics) to compute the accuracy between two lists of values (y_true, the list of “correct” labels, and y_pred, the list of predictions made by the classifier). Since you already have both these lists (y for the ground truth, and the result of the predict() method for the prediction), you can already compute the accuracy of your classifier.

# %%
#to compare with predicted y
y_true = y

# %%
y_pred = wineclassifier.predict(X)

# %%
#importing accuracy_score
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_true, y_pred)
# Out:
# 1.0

# %% [markdown]
# • What result do you get?

# %% [markdown]
# The accuracy score is 1.0.

# %% [markdown]
# • Does this result seem particularly high/low?

# %% [markdown]
# It is high.

# %% [markdown]
# • Why do you think that is?

# %% [markdown]
# The decision tree classifier we used was built based on the whole dataset with 13 features in X and y_true. Hence, the classifier would return the same predicted y values as the whole dataset was again used to predict the y_pred.
# Therefore, the accuracy score is 1.0

# %% [markdown]
# 6, Now, we can split our dataset into a training set and a test set. We will use the training set to train a model, and to assess its performance with the test set. Sklearn offers the train_test_split() function to split any number of arrays (all having the same length on the first dimension) into two sets. You can use an 80/20 train/test split. If used correctly, you will get 4 arrays: X_train, X_test, y_train, y_test.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 17, test_size = 0.2)

# %%
#Let us check the shape of the arrays to see the number of elements
X_train.shape
# Out:
# (142, 13)

# %%
X_test.shape
# Out:
# (36, 13)

# %%
y_train.shape
# Out:
# (142, 1)

# %%
y_test.shape
# Out:
# (36, 1)

# %%
# The dataset has been split into 80:20 of training and testing data

# %% [markdown]
# 7, Now, train a new model using (X_train, y_train). Then, compute the accuracy with (X_test, y_test).

# %%
wineclassifier2 = DecisionTreeClassifier()

# %%
#new decision tree classifier with training data
wineclassifier2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#predicting y values for test X values
y_pred2 = wineclassifier2.predict(X_test)

# %%
#accuracy score for this data
accuracy_score(y_test, y_pred2)
# Out:
# 0.9722222222222222

# %% [markdown]
# • How does this value compare to the previously computed one?

# %% [markdown]
# The accuracy score of the model is close to 1 and not 1, which means there were some classes that were predicted wrong.

# %%
#This value is close to 1. We can check the number of correct values with normalize = False
accuracy_score(y_test, y_pred2, normalize = False)
# Out:
# 35.0

# %%
#35 entries out of the 36 test data were predicted correctly with the decision tree classifier model.

# %% [markdown]
# • Is this a more reasonable value? Why?

# %% [markdown]
# It is a more reasonable value as we cannot generate all possible classifications with the limited number of training data.
# It is also impossible to collect every possible dataset to train our model as it is time consuming.

# %% [markdown]
# • Compute other metrics (e.g. precision, recall, F1 score) using the respective functions (precision_score, recall_score, f1_score).

# %%
#The classification_report function gives the precision, recall and F1 score
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         8
#            2       0.94      1.00      0.97        16
#            3       1.00      0.92      0.96        12
#
#     accuracy                           0.97        36
#    macro avg       0.98      0.97      0.98        36
# weighted avg       0.97      0.97      0.97        36

# %% [markdown]
# 8, So far, you have only used “default” decision trees (i.e. decision trees using the default configuration). The “default” decision tree might not be the best option in terms of performance to fit our dataset. In this exercise, you will perform a “grid search”: you will define a set of possible configurations and, for each configuration, build a classifier. Then, you will test the performance of each classifier and identify that configuration that produces the best model.
#
#
# On the official documentation for DecisionTreeClassifier you can find a list of all parameters you can modify. Identify some of the parameters that, based on your theoretical knowledge of decision trees, might affect the performance of the tree. For each of these parameters, define a set of possible values (the official documentation provides additional information about the possible values that can be used). For example, we can identify these two parameters:
#
#
# • max_depth, which defines the maximum depth of the decision tree, can be set to None (i.e. unbounded depth), or to values such as 2, 4, 8 (we already know from previous exercises the approximate depth the tree can reach with this dataset)
#
#
# • splitter, which can be set to either best (in which case, for each split, the algorithm will try all possible splits), or random (in this case, the algorithm will try N random splits on various features and select the best one)

# %%
wineclassifier.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
#There are 13 parameters in the DecisionTreeClassifier 
#defining a parameter grid
grid_wine = {
    'ccp_alpha' : [0, 0.04],
    'criterion' : ['gini', 'entropy'],
    'max_depth' : range(0, 6), #we know the maximum depth is 5
    'splitter' : ['best', 'random']
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
wineclassifier3 = DecisionTreeClassifier()

# %%
gridwineclassifier = GridSearchCV(estimator = wineclassifier3, param_grid = grid_wine, scoring = 'accuracy')

# %%
gridwineclassifier.fit(X_train, y_train)
# Out:
# C:\Users\willy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 40 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\willy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
#getting the best parameters
print("Best parameters:", gridwineclassifier.best_params_)
# Out:
# Best parameters: {'ccp_alpha': 0, 'criterion': 'gini', 'max_depth': 5, 'splitter': 'best'}

# %%
#Building a model with the parameters and seeing the accuracy with our test data
wineclassifierbest = DecisionTreeClassifier(ccp_alpha = 0, criterion = 'gini', max_depth = 5, splitter = 'best')

# %%
wineclassifierbest.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0, max_depth=5)

# %%
y_pred_best = wineclassifierbest.predict(X_test)

# %%
accuracy_score(y_test, y_pred_best)
# Out:
# 0.9444444444444444

# %%
#However the accuracy is lesser than our previous model

# %% [markdown]
# 9, In the previous exercise, you searched for the best configuration among a list of possible alternatives. Since we used our test data to select the model, you may be overfitting on the test data (you may have selected the configuration that works best for the test set, but which may not be as good on new data). Typically, you do not want to use the test set for tuning the model’s hyperparameters, since the test set should only be used as a final evaluation.
#
#
# For this reason, datasets are typically splitted into
#
#
# • Training set: used to create the model.
#
#
# • Validation set: used to assess how good each configuration of a classifier is.
#
#
# • Test set: used at the end of the hyperparameter tuning, to assess how good our final model is.
#
#
# However, it often happens that only a limited amount of data is available. In these cases, it is wasteful to only use a small fraction of the dataset for the actual training. In these cases, cross-validation can be used to “get rid” of the validation set. One popular method of is the k-fold cross-validation. In this, the training set is split into k partitions. K-1 are used for the training, the other one is used validation. This is repeated until all partitions have been used once for validation.
#
#
# Sklearn offers the KFold class for doing k-fold cross-validation. You can use this class.
# For each fold, you can use the training data to train each classifier (i.e. decision trees with different configurations) and measure the performance on the validation data. You can then aggregate the information extracted (e.g. by computing the overall accuracy from the accuracies on each fold) and select the best performing model. After you select one model, you can assess its performance on Test set.

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
kfold = KFold(n_splits = 5, shuffle = True, random_state = 27)

# %%
wineclassifier4 = DecisionTreeClassifier()
gridwineclassifier2 = GridSearchCV(estimator = wineclassifier4, param_grid = grid_wine, cv = kfold, scoring = 'accuracy')

# %%
gridwineclassifier2.fit(X_train, y_train)
# Out:
# C:\Users\willy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 40 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\willy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
print(gridwineclassifier2.best_estimator_)
# Out:
# DecisionTreeClassifier(ccp_alpha=0, max_depth=5, splitter='random')

# %%
print(gridwineclassifier2.best_score_)
# Out:
# 0.9219211822660099

# %%
#testing on our test data
dtc = DecisionTreeClassifier(ccp_alpha=0, max_depth=5, splitter='random')
dtc.fit(X_train, y_train)
y_pred_best2 = dtc.predict(X_test)

# %%
accuracy_score(y_test, y_pred_best2)
# Out:
# 0.9722222222222222

# %%
#The accuracy of the model is almost 1 with 35 entries classified correctly out of 36. And it is better than the previous model.
