# %%
import pandas as pd

# %%
data = pd.read_csv("500hits.csv", encoding = "latin-1")

# %%
data
# Out:
#              PLAYER  YRS     G     AB     R     H   2B   3B   HR   RBI    BB  \
# 0           Ty Cobb   24  3035  11434  2246  4189  724  295  117   726  1249
# 1       Stan Musial   22  3026  10972  1949  3630  725  177  475  1951  1599
# 2      Tris Speaker   22  2789  10195  1882  3514  792  222  117   724  1381
# 3       Derek Jeter   20  2747  11195  1923  3465  544   66  260  1311  1082
# 4      Honus Wagner   21  2792  10430  1736  3430  640  252  101     0   963
# ..              ...  ...   ...    ...   ...   ...  ...  ...  ...   ...   ...
# 460        Jim Wynn   15  1920   6653  1105  1665  285   39  291   964  1224
# 461    Jorge Posada   17  1829   6092   900  1664  379   10  275  1065   936
# 462  Brady Anderson   15  1834   6499  1062  1661  338   67  210   761   960
# 463    Cookie Rojas   16  1822   6309   714  1660  254   25   54   593   396
# 464   Mickey Rivers   15  1468   5629   785  1660  247   71   61   499   266
#
#        SO   SB   CS     BA  HOF
# ...

# %%
data.describe()
# Out:
#               YRS            G            AB            R            H  \
# count  465.000000   465.000000    465.000000   465.000000   465.000000
# mean    17.049462  2048.698925   7511.455914  1150.313978  2170.247312
# std      2.765186   354.391805   1294.065992   289.635071   424.190773
# min     11.000000  1331.000000   4981.000000   601.000000  1660.000000
# 25%     15.000000  1802.000000   6523.000000   936.000000  1838.000000
# 50%     17.000000  1993.000000   7241.000000  1104.000000  2076.000000
# 75%     19.000000  2247.000000   8180.000000  1296.000000  2375.000000
# max     26.000000  3308.000000  12364.000000  2295.000000  4189.000000
#
#                2B          3B          HR          RBI          BB  \
# count  465.000000  465.000000  465.000000   465.000000   465.00000
# mean   380.952688   78.554839  201.049462   894.260215   783.56129
# std     96.483460   49.363030  143.622664   486.193456   327.43195
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PLAYER  465 non-null    object
#  1   YRS     465 non-null    int64
#  2   G       465 non-null    int64
#  3   AB      465 non-null    int64
#  4   R       465 non-null    int64
#  5   H       465 non-null    int64
#  6   2B      465 non-null    int64
#  7   3B      465 non-null    int64
#  8   HR      465 non-null    int64
#  9   RBI     465 non-null    int64
#  10  BB      465 non-null    int64
#  11  SO      465 non-null    int64
#  12  SB      465 non-null    int64
#  13  CS      465 non-null    int64
#  14  BA      465 non-null    float64
#  15  HOF     465 non-null    int64
# dtypes: float64(1), int64(14), object(1)
# memory usage: 58.3+ KB

# %%
data = data.drop(columns = ['PLAYER', 'CS'])
data.head()
# Out:
#    YRS     G     AB     R     H   2B   3B   HR   RBI    BB    SO   SB     BA  \
# 0   24  3035  11434  2246  4189  724  295  117   726  1249   357  892  0.366
# 1   22  3026  10972  1949  3630  725  177  475  1951  1599   696   78  0.331
# 2   22  2789  10195  1882  3514  792  222  117   724  1381   220  432  0.345
# 3   20  2747  11195  1923  3465  544   66  260  1311  1082  1840  358  0.310
# 4   21  2792  10430  1736  3430  640  252  101     0   963   327  722  0.329
#
#    HOF
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
X = data.iloc[:, 0:13]
y = data['HOF']

# %%
X.head()
# Out:
#    YRS     G     AB     R     H   2B   3B   HR   RBI    BB    SO   SB     BA
# 0   24  3035  11434  2246  4189  724  295  117   726  1249   357  892  0.366
# 1   22  3026  10972  1949  3630  725  177  475  1951  1599   696   78  0.331
# 2   22  2789  10195  1882  3514  792  222  117   724  1381   220  432  0.345
# 3   20  2747  11195  1923  3465  544   66  260  1311  1082  1840  358  0.310
# 4   21  2792  10430  1736  3430  640  252  101     0   963   327  722  0.329

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: HOF, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 17, test_size = 0.2)

# %%
X_train.shape
# Out:
# (372, 13)

# %%
X_test.shape
# Out:
# (93, 13)

# %%
y_train.shape
# Out:
# (372,)

# %%
y_test.shape
# Out:
# (93,)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtc.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[49 12]
#  [12 20]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        61
#            1       0.62      0.62      0.62        32
#
#     accuracy                           0.74        93
#    macro avg       0.71      0.71      0.71        93
# weighted avg       0.74      0.74      0.74        93

# %%
dtc.feature_importances_
# Out:
# array([0.02525798, 0.0154869 , 0.02052578, 0.04113233, 0.4016772 ,
#        0.04325963, 0.04400595, 0.01735894, 0.07925991, 0.10568316,
#        0.04547361, 0.05836738, 0.10251123])

# %%
featureImportances = {'feature_importance' : dtc.feature_importances_.tolist(), 'index' : col1[0:13]}

# %%
featureImportances = pd.DataFrame(featureImportances)
featureImportances
# Out:
#     feature_importance index
# 0             0.025258   YRS
# 1             0.015487     G
# 2             0.020526    AB
# 3             0.041132     R
# 4             0.401677     H
# 5             0.043260    2B
# 6             0.044006    3B
# 7             0.017359    HR
# 8             0.079260   RBI
# 9             0.105683    BB
# 10            0.045474    SO
# 11            0.058367    SB
# 12            0.102511    BA

# %%
featureImportances.sort_values(by = 'feature_importance', ascending = False)
# Out:
#     feature_importance index
# 4             0.401677     H
# 9             0.105683    BB
# 12            0.102511    BA
# 8             0.079260   RBI
# 11            0.058367    SB
# 10            0.045474    SO
# 6             0.044006    3B
# 5             0.043260    2B
# 3             0.041132     R
# 0             0.025258   YRS
# 2             0.020526    AB
# 7             0.017359    HR
# 1             0.015487     G

# %%
dtc2 = DecisionTreeClassifier(criterion = 'entropy', ccp_alpha = 0.04)

# %%
dtc2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.04, criterion='entropy')

# %%
y_pred2 = dtc2.predict(X_test)

# %%
confusion_matrix(y_test, y_pred2)
# Out:
# array([[50, 11],
#        [ 9, 23]])

# %%
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.83        61
#            1       0.68      0.72      0.70        32
#
#     accuracy                           0.78        93
#    macro avg       0.76      0.77      0.77        93
# weighted avg       0.79      0.78      0.79        93

# %%
featureImportances = {'feature_importance' : dtc2.feature_importances_.tolist(), 'index' : col1[0:13]}
featureImportances = pd.DataFrame(featureImportances)
featureImportances
# Out:
#     feature_importance index
# 0             0.000000   YRS
# 1             0.000000     G
# 2             0.000000    AB
# 3             0.000000     R
# 4             0.837977     H
# 5             0.000000    2B
# 6             0.000000    3B
# 7             0.000000    HR
# 8             0.000000   RBI
# 9             0.000000    BB
# 10            0.000000    SO
# 11            0.000000    SB
# 12            0.162023    BA

# %%
featureImportances.sort_values(by = 'feature_importance', ascending = False)
# Out:
#     feature_importance index
# 4             0.837977     H
# 12            0.162023    BA
# 0             0.000000   YRS
# 2             0.000000    AB
# 1             0.000000     G
# 3             0.000000     R
# 5             0.000000    2B
# 7             0.000000    HR
# 6             0.000000    3B
# 8             0.000000   RBI
# 9             0.000000    BB
# 10            0.000000    SO
# 11            0.000000    SB

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7419354838709677

# %%
accuracy_score(y_test, y_pred2)
# Out:
# 0.7849462365591398
